# %%
import os
os.chdir(r'F:\OneDrive\LOCI_JENU\Data\QD\mink_pyc')
import sdt_tools
import reflibv2
import gui_tools
import glob
import spc_asc
# Out:
# C:\Python27\lib\site-packages\IPython\html.py:14: ShimWarning: The `IPython.html` package has been deprecated since IPython 4.0. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#   "`IPython.html.widgets` has moved to `ipywidgets`.", ShimWarning)

# %%
# %pylab
# %matplotlib inline
matplotlib.style.use('seaborn-poster')
# Out:
# Using matplotlib backend: TkAgg
# Populating the interactive namespace from numpy and matplotlib

# %%
import tifffile as tf
import pandas as pd
import seaborn as sns

# %%
#os.chdir(r'F:\USER_FOLDERS\_JenuChacko\20180626_\60x_10A_NBF_tests\NBF_control_\time_sserries\tpoints')
os.chdir(r'F:\USER_FOLDERS\_JenuChacko\20180626_\60x_10A_NBF_tests\PFA_control\tpoints')

# %%
import glob
fl=glob.glob('*.tif')
fl
# Out:
# ['SUM_pfa_ts-1.tif', 'SUM_pfa_ts-2.tif', 'SUM_pfa_ts-3.tif']

# %%
for i in fl:
    arr=tf.TiffFile(i)
    arr=arr.asarray()
    sns.kdeplot(arr[(arr>arr.mean())],label=i)
#yscale('log')
