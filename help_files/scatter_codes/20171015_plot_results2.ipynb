# %%
import os
import glob
import seaborn as sns
import pandas as pd

# %%
# %pylab
# %matplotlib inline
# Out:
# Using matplotlib backend: TkAgg
# Populating the interactive namespace from numpy and matplotlib

# %%
df=pd.read_excel('results_.xlsx')

# %%
sns.boxplot(x='cell',y='iTM',data=df,order=['PANC','HPV','CA1D','10A'])

# %%
df.columns
# Out:
# Index([u'filename', u'conc', u'r_conc', u'cell', u'Intensity', u'TM', u'f1',
#        u'fileindex', u'iTM', u'seeding_conf', u'seed_N'],
#       dtype='object')

# %%
#g=sns.FacetGrid(df,col='cell')
#g.map(sns.violinplot,x='r_conc',y='iTM',data=df)
sns.factorplot(x='r_conc',y='iTM',data=df,kind='strip',col='cell')

# %%
sns.barplot(x='r_conc',y='iTM',data=df,hue_order=['PANC','HPV','CA1D','10A'],hue='cell')

# %%
df.columns
# Out:
# Index([u'filename', u'conc', u'r_conc', u'cell', u'Intensity', u'TM', u'f1',
#        u'fileindex', u'iTM', u'seeding_conf', u'seed_N'],
#       dtype='object')

# %%
sns.barplot(x='seed_N',y='iTM',data=df,hue_order=['10A','HPV',],hue='cell')
ylim([2000,3000])
figure()
sns.boxplot(x='seed_N',y='iTM',data=df,hue_order=['CA1D','PANC'],hue='cell')

# %%
sns.stripplot(x='seed_N',y='iTM',data=df.loc[df['cell']=='10A'],jitter=.3)

# %%
sns.stripplot(x='seed_N',y='iTM',data=df.loc[df['cell']=='CA1D'],jitter=.3)

# %%
sns.stripplot(x='seed_N',y='iTM',data=df.loc[df['cell']=='HPV'],jitter=.3)

# %%
sns.stripplot(x='seed_N',y='iTM',data=df.loc[df['cell']=='PANC'],jitter=.3)

# %%
os.chdir(r'D:\JenuChacko\20171013_confluency')
df2=pd.read_excel('results_.xls')

# %%
df2.columns
# Out:
# Index([u'filename', u'Intensity', u'TM', u'conf', u'seeding_conf', u'f1',
#        u'fileindex', u'folder', u'iTM'],
#       dtype='object')

# %%
sns.factorplot(x='conf',y='iTM',data=df2,kind='strip',col='folder')

# %%
#sns.factorplot(x='conf',y='iTM',data=df2,kind='box',col='folder')

# %%
sns.stripplot(x='conf',y='iTM',data=df2.loc[df2['folder']=='PANC'],jitter=.3)
figure()
sns.stripplot(x='conf',y='iTM',data=df2.loc[df2['folder']=='HPV'],jitter=.3)
figure()
sns.stripplot(x='conf',y='iTM',data=df2.loc[df2['folder']=='CA1D'],jitter=.3)
figure()
sns.stripplot(x='conf',y='iTM',data=df2.loc[df2['folder']=='10A'],jitter=.3)

# %%
print df.seeding_conf.unique()

print df2.seeding_conf.unique()
# Out:
# [ 0.04627273  0.044875    0.067       0.115875    0.344625    0.028125
#   0.202875    0.397       0.42354545  0.02588889  0.131       0.06072727
#   0.21075     0.089375    0.06875     0.0605      0.125       0.281125
#   0.32966667  0.75511111  0.66316667]
# [ 0.03  0.07  0.08  0.17  0.33  0.5   0.67  0.83  1.  ]

# %%
df.columns
# Out:
# Index([u'filename', u'conc', u'r_conc', u'cell', u'Intensity', u'TM', u'f1',
#        u'fileindex', u'iTM', u'seeding_conf', u'seed_N'],
#       dtype='object')

# %%
sns.lmplot(x='seeding_conf',y='iTM',col='cell',data=df,col_order=['10A','CA1D','PANC','HPV'])

# %%
sns.lmplot(x='seeding_conf',y='iTM',col='folder',data=df2)
