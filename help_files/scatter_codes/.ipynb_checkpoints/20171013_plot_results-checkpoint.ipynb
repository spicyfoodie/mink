# %%
import os
import glob
import seaborn as sns
import pandas as pd

# %%
# %pylab
# %matplotlib inline
# Out:
# Using matplotlib backend: TkAgg
# Populating the interactive namespace from numpy and matplotlib

# %%
df=pd.read_excel('results_.xlsx')

# %%
sns.boxplot(x='cell',y='iTM',data=df,order=['PANC','HPV','CA1D','10A'])

# %%
df.columns
# Out:
# Index([u'filename', u'conc', u'r_conc', u'cell', u'Intensity', u'TM', u'f1',
#        u'fileindex', u'iTM'],
#       dtype='object')

# %%
sns.boxplot(x='r_conc',y='iTM',data=df,hue_order=['PANC','HPV','CA1D','10A'],hue='cell')

# %%
df.columns
# Out:
# Index([u'filename', u'conc', u'r_conc', u'cell', u'Intensity', u'TM', u'f1',
#        u'fileindex', u'iTM', u'seeding_conf', u'seed_N'],
#       dtype='object')

# %%
sns.boxplot(x='seed_N',y='iTM',data=df,hue_order=['10A','HPV',],hue='cell')
figure()
sns.boxplot(x='seed_N',y='iTM',data=df,hue_order=['CA1D','PANC'],hue='cell')
