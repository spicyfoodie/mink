# %%
import tifffile

# %%
import os
os.chdir(r'F:\OneDrive\LOCI_JENU\Data\QD\mink_pyc')

# %%
import sdt_tools
import reflibv2
import gui_tools
import glob
import spc_asc
# Out:
# C:\Python27\lib\site-packages\IPython\html.py:14: ShimWarning: The `IPython.html` package has been deprecated since IPython 4.0. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#   "`IPython.html.widgets` has moved to `ipywidgets`.", ShimWarning)

# %%
import run_mink

# %%
import load_pyc_for_jupyter
# Out:
# C:\Python27\lib\site-packages\IPython\html.py:14: ShimWarning: The `IPython.html` package has been deprecated since IPython 4.0. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#   "`IPython.html.widgets` has moved to `ipywidgets`.", ShimWarning)
# F:\OneDrive\LOCI_JENU\Data\QD\mink_pyc
# # groups =  2
# group #15b01a  with #files = 15
# group #e50000  with #files = 14
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# mink_asc_mil.pyc in action8(self)
#
# AttributeError: 'module' object has no attribute 'plot_univ_circle'
# F:\USER_FOLDERS\_JenuChacko\20180626_\20x_10A_NBF_trest\control2_
# closing <mink_asc_mil.control_window object at 0x0000000020090168>
# closing <PyQt4.QtGui.QWidget object at 0x000000002C5B6AF8>
# closing <mink_asc_mil.mpl_loader object at 0x000000002039E168>
# ...

# %%
import os

# %%
import glob

# %%
os.chdir(r'F:\USER_FOLDERS\_JenuChacko\20180626_\10X_10A_NBF_tests\control03_')
fl=glob.glob(r'*.sdt')

# %%
#ord('B')

# %%
#for i in fl:
    #print ord(i.split('_')[1][-1])-64,i.split('_')[2][-2:]

# %%
# %%time
LT=[]
for i in fl:
    print i
    arr=sdt_tools.read_sdt(i)
    data=arr[0]
    #t=arr[1]
    #print arr[2]
    #plot(t*10**9,data.sum(2).sum(1))
    LT.append(data.sum(2).sum(1))
# Out:
# control_60sec_nointerval_TP00_SP0_Z0.sdt
#  enforcing loci-written spcfile
#  detected channels : 1
# control_60sec_nointerval_TP01_SP0_Z0.sdt
#  enforcing loci-written spcfile
#  detected channels : 1
# control_60sec_nointerval_TP02_SP0_Z0.sdt
#  enforcing loci-written spcfile
#  detected channels : 1
# control_60sec_nointerval_TP03_SP0_Z0.sdt
#  enforcing loci-written spcfile
#  detected channels : 1
# control_60sec_nointerval_TP04_SP0_Z0.sdt
#  enforcing loci-written spcfile
#  detected channels : 1
# control_60sec_nointerval_TP05_SP0_Z0.sdt
#  enforcing loci-written spcfile
#  detected channels : 1
# control_60sec_nointerval_TP06_SP0_Z0.sdt
#  enforcing loci-written spcfile
#  detected channels : 1
# control_60sec_nointerval_TP07_SP0_Z0.sdt
#  enforcing loci-written spcfile
#  detected channels : 1
# control_60sec_nointerval_TP08_SP0_Z0.sdt
#  enforcing loci-written spcfile
#  detected channels : 1
# control_60sec_nointerval_TP09_SP0_Z0.sdt
#  enforcing loci-written spcfile
# ...

# %%
for ix,i in enumerate(fl):
    print ix, i
# Out:
# 0 control_60sec_nointerval_TP00_SP0_Z0.sdt
# 1 control_60sec_nointerval_TP01_SP0_Z0.sdt
# 2 control_60sec_nointerval_TP02_SP0_Z0.sdt
# 3 control_60sec_nointerval_TP03_SP0_Z0.sdt
# 4 control_60sec_nointerval_TP04_SP0_Z0.sdt
# 5 control_60sec_nointerval_TP05_SP0_Z0.sdt
# 6 control_60sec_nointerval_TP06_SP0_Z0.sdt
# 7 control_60sec_nointerval_TP07_SP0_Z0.sdt
# 8 control_60sec_nointerval_TP08_SP0_Z0.sdt
# 9 control_60sec_nointerval_TP09_SP0_Z0.sdt
# 10 control_60sec_nointerval_TP10_SP0_Z0.sdt
# 11 control_60sec_nointerval_TP11_SP0_Z0.sdt
# 12 control_60sec_nointerval_TP12_SP0_Z0.sdt
# 13 control_60sec_nointerval_TP13_SP0_Z0.sdt
# 14 control_60sec_nointerval_TP14_SP0_Z0.sdt
# 15 control_60sec_nointerval_TP15_SP0_Z0.sdt
# 16 control_60sec_nointerval_TP16_SP0_Z0.sdt
# 17 control_60sec_nointerval_TP17_SP0_Z0.sdt
# 18 control_60sec_nointerval_TP18_SP0_Z0.sdt
# 19 control_60sec_nointerval_TP19_SP0_Z0.sdt
# 20 control_60sec_nointerval_TP20_SP0_Z0.sdt
# ...

# %%
# %pylab
# %matplotlib inline

matplotlib.style.use('seaborn-poster')
# Out:
# Using matplotlib backend: TkAgg
# Populating the interactive namespace from numpy and matplotlib

# %%
figure(figsize=[20,10])

for i in LT[:2]:
    plot(np.array(i).astype(float)/i.max(),'.k')

    
#for i in LT[20:30]:
#    plot(np.array(i).astype(float)/i.max(),'.r')

for i in LT[30:]:
    plot(np.array(i).astype(float)/i.max(),'.b')

#for i in LT[80:]:
#    plot(np.array(i).astype(float)/i.max(),'.y')

yscale('log')
title('inconclusive- black:NADH red:NADH+NBF(low counts) blue:NADH+NBF high counts')

# %%
imshow(data.sum(0),cmap='jet')

# %%
plot(data[:,:128,:128].sum(2).sum(1),'.k')
plot(data[:,:128,128:].sum(2).sum(1),'.g')
plot(data[:,128:,:128].sum(2).sum(1),'.r')
plot(data[:,128:,128:].sum(2).sum(1),'.b')
yscale('log')

# %%
imshow(data[:,128:,:128].sum(0),cmap=gui_tools.jetblk,vmin=15,vmax=70)
colorbar()
grid('off')
