# %%
import tifffile

# %%
import os
os.chdir(r'F:\OneDrive\LOCI_JENU\Data\QD\mink_pyc')

# %%
import sdt_tools
import reflibv2
import gui_tools
import glob
import spc_asc
# Out:
# C:\Python27\lib\site-packages\IPython\html.py:14: ShimWarning: The `IPython.html` package has been deprecated since IPython 4.0. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#   "`IPython.html.widgets` has moved to `ipywidgets`.", ShimWarning)

# %%
import run_mink

# %%
import load_pyc_for_jupyter
# Out:
# F:\OneDrive\LOCI_JENU\Data\QD\mink_pyc
# closing <mink_asc_mil.control_window object at 0x000000001F3A0168>
# closing <mink_asc_mil.mpl_loader object at 0x000000001F78C708>
# closing <PyQt4.QtGui.QFrame object at 0x000000002A147EE8>
# closing <PyQt4.QtGui.QMenu object at 0x000000002A147F78>
# closing <mink_asc_mil.mpl_loader object at 0x000000002A147558>
# closing <PyQt4.QtGui.QWidget object at 0x00000000279C7048>
# closing <mink_asc_mil.file_list_holder object at 0x000000001F3A0828>
# closing <mink_asc_mil.multi_preview_window object at 0x000000001F3A8558>
# closing <mink_asc_mil.mpl_loader object at 0x0000000027398D38>
# closing <PyQt4.QtGui.QMenu object at 0x00000000279C70D8>
# closing <PyQt4.QtGui.QMenu object at 0x00000000279C7168>
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# C:\Python27\lib\site-packages\IPython\core\formatters.pyc in __call__(self, obj)
#     332                 pass
#     333             else:
# --> 334                 return printer(obj)
#     335             # Finally look for special method names
#     336             method = get_real_method(obj, self.print_method)
#
# C:\Python27\lib\site-packages\IPython\core\pylabtools.pyc in <lambda>(fig)
#     245
#     246     if 'png' in formats:
# --> 247         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     248     if 'retina' in formats or 'png2x' in formats:
#     249         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# C:\Python27\lib\site-packages\IPython\core\pylabtools.pyc in print_figure(fig, fmt, bbox_inches, **kwargs)
#     129
#     130     bytes_io = BytesIO()
# --> 131     fig.canvas.print_figure(bytes_io, **kw)
#     132     data = bytes_io.getvalue()
#     133     if fmt == 'svg':
#
# C:\Python27\lib\site-packages\matplotlib\backends\backend_qt5agg.pyc in print_figure(self, *args, **kwargs)
#     205     def print_figure(self, *args, **kwargs):
#     206         FigureCanvasAgg.print_figure(self, *args, **kwargs)
# --> 207         self.draw()
#     208
#     209
#
# C:\Python27\lib\site-packages\matplotlib\backends\backend_qt5agg.pyc in draw(self)
#     161         # uses the result of the draw() to update plot elements.
#     162         FigureCanvasAgg.draw(self)
# --> 163         self.update()
#     164
#     165     def draw_idle(self):
#
# RuntimeError: wrapped C/C++ object of type FigureCanvasQTAgg has been deleted
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# C:\Python27\lib\site-packages\IPython\core\formatters.pyc in __call__(self, obj)
#     332                 pass
#     333             else:
# --> 334                 return printer(obj)
#     335             # Finally look for special method names
#     336             method = get_real_method(obj, self.print_method)
#
# C:\Python27\lib\site-packages\IPython\core\pylabtools.pyc in <lambda>(fig)
#     245
#     246     if 'png' in formats:
# --> 247         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     248     if 'retina' in formats or 'png2x' in formats:
#     249         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# C:\Python27\lib\site-packages\IPython\core\pylabtools.pyc in print_figure(fig, fmt, bbox_inches, **kwargs)
#     129
#     130     bytes_io = BytesIO()
# --> 131     fig.canvas.print_figure(bytes_io, **kw)
#     132     data = bytes_io.getvalue()
#     133     if fmt == 'svg':
#
# C:\Python27\lib\site-packages\matplotlib\backends\backend_qt5agg.pyc in print_figure(self, *args, **kwargs)
#     205     def print_figure(self, *args, **kwargs):
#     206         FigureCanvasAgg.print_figure(self, *args, **kwargs)
# --> 207         self.draw()
#     208
#     209
#
# C:\Python27\lib\site-packages\matplotlib\backends\backend_qt5agg.pyc in draw(self)
#     161         # uses the result of the draw() to update plot elements.
#     162         FigureCanvasAgg.draw(self)
# --> 163         self.update()
#     164
#     165     def draw_idle(self):
#
# RuntimeError: wrapped C/C++ object of type FigureCanvasQTAgg has been deleted
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# C:\Python27\lib\site-packages\IPython\core\formatters.pyc in __call__(self, obj)
#     332                 pass
#     333             else:
# --> 334                 return printer(obj)
#     335             # Finally look for special method names
#     336             method = get_real_method(obj, self.print_method)
#
# C:\Python27\lib\site-packages\IPython\core\pylabtools.pyc in <lambda>(fig)
#     245
#     246     if 'png' in formats:
# --> 247         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     248     if 'retina' in formats or 'png2x' in formats:
#     249         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# C:\Python27\lib\site-packages\IPython\core\pylabtools.pyc in print_figure(fig, fmt, bbox_inches, **kwargs)
#     129
#     130     bytes_io = BytesIO()
# --> 131     fig.canvas.print_figure(bytes_io, **kw)
#     132     data = bytes_io.getvalue()
#     133     if fmt == 'svg':
#
# C:\Python27\lib\site-packages\matplotlib\backends\backend_qt5agg.pyc in print_figure(self, *args, **kwargs)
#     205     def print_figure(self, *args, **kwargs):
#     206         FigureCanvasAgg.print_figure(self, *args, **kwargs)
# --> 207         self.draw()
#     208
#     209
#
# C:\Python27\lib\site-packages\matplotlib\backends\backend_qt5agg.pyc in draw(self)
#     161         # uses the result of the draw() to update plot elements.
#     162         FigureCanvasAgg.draw(self)
# --> 163         self.update()
#     164
#     165     def draw_idle(self):
#
# RuntimeError: wrapped C/C++ object of type FigureCanvasQTAgg has been deleted

# %%
import os

# %%
import glob

# %%
os.chdir(r'F:\USER_FOLDERS\_JenuChacko\20180625_\60x_12NA_WI_\nadh')
fl=glob.glob(r'*.sdt')

# %%
#ord('B')

# %%
#for i in fl:
    #print ord(i.split('_')[1][-1])-64,i.split('_')[2][-2:]

# %%
# %%time
LT=[]
for i in fl:
    print i
    arr=sdt_tools.read_sdt(i)
    data=arr[0]
    #t=arr[1]
    #print arr[2]
    #plot(t*10**9,data.sum(2).sum(1))
    LT.append(data.sum(2).sum(1))
# Out:
# time_serieA_TP00_SP0_Z0.sdt
#  enforcing loci-written spcfile
#  detected channels : 1
# time_serieA_TP01_SP0_Z0.sdt
#  enforcing loci-written spcfile
#  detected channels : 1
# time_serieA_TP02_SP0_Z0.sdt
#  enforcing loci-written spcfile
#  detected channels : 1
# time_serieA_TP03_SP0_Z0.sdt
#  enforcing loci-written spcfile
#  detected channels : 1
# time_serieA_TP04_SP0_Z0.sdt
#  enforcing loci-written spcfile
#  detected channels : 1
# time_serieA_TP05_SP0_Z0.sdt
#  enforcing loci-written spcfile
#  detected channels : 1
# time_serieA_TP06_SP0_Z0.sdt
#  enforcing loci-written spcfile
#  detected channels : 1
# time_serieA_TP07_SP0_Z0.sdt
#  enforcing loci-written spcfile
#  detected channels : 1
# time_serieA_TP08_SP0_Z0.sdt
#  enforcing loci-written spcfile
#  detected channels : 1
# time_serieA_TP09_SP0_Z0.sdt
#  enforcing loci-written spcfile
#  detected channels : 1
# time_serieA_TP10_SP0_Z0.sdt
#  enforcing loci-written spcfile
#  detected channels : 1
# time_serieA_TP11_SP0_Z0.sdt
#  enforcing loci-written spcfile
#  detected channels : 1
# time_serieA_TP12_SP0_Z0.sdt
#  enforcing loci-written spcfile
#  detected channels : 1
# time_serieA_TP13_SP0_Z0.sdt
#  enforcing loci-written spcfile
#  detected channels : 1
# time_serieA_TP14_SP0_Z0.sdt
#  enforcing loci-written spcfile
#  detected channels : 1
# time_serieA_TP15_SP0_Z0.sdt
#  enforcing loci-written spcfile
#  detected channels : 1
# time_serieA_TP16_SP0_Z0.sdt
#  enforcing loci-written spcfile
#  detected channels : 1
# time_serieA_TP17_SP0_Z0.sdt
#  enforcing loci-written spcfile
#  detected channels : 1
# time_serieA_TP18_SP0_Z0.sdt
#  enforcing loci-written spcfile
#  detected channels : 1
# time_serieA_TP19_SP0_Z0.sdt
#  enforcing loci-written spcfile
#  detected channels : 1
# time_serieA_TP20_SP0_Z0.sdt
#  enforcing loci-written spcfile
#  detected channels : 1
# time_serieA_TP21_SP0_Z0.sdt
#  enforcing loci-written spcfile
#  detected channels : 1
# time_serieA_TP22_SP0_Z0.sdt
#  enforcing loci-written spcfile
#  detected channels : 1
# time_serieA_TP23_SP0_Z0.sdt
#  enforcing loci-written spcfile
#  detected channels : 1
# time_serieA_TP24_SP0_Z0.sdt
#  enforcing loci-written spcfile
#  detected channels : 1
# time_serieA_TP25_SP0_Z0.sdt
#  enforcing loci-written spcfile
#  detected channels : 1
# time_serieA_TP26_SP0_Z0.sdt
#  enforcing loci-written spcfile
#  detected channels : 1
# time_serieA_TP27_SP0_Z0.sdt
#  enforcing loci-written spcfile
#  detected channels : 1
# time_serieA_TP28_SP0_Z0.sdt
#  enforcing loci-written spcfile
#  detected channels : 1
# time_serieA_TP29_SP0_Z0.sdt
#  enforcing loci-written spcfile
#  detected channels : 1
# time_serieA_TP30_SP0_Z0.sdt
#  enforcing loci-written spcfile
#  detected channels : 1
# time_serieA_TP31_SP0_Z0.sdt
#  enforcing loci-written spcfile
#  detected channels : 1
# time_serieA_TP32_SP0_Z0.sdt
#  enforcing loci-written spcfile
#  detected channels : 1
# time_serieA_TP33_SP0_Z0.sdt
#  enforcing loci-written spcfile
#  detected channels : 1
# time_serieA_TP34_SP0_Z0.sdt
#  enforcing loci-written spcfile
#  detected channels : 1
# time_serieA_TP35_SP0_Z0.sdt
#  enforcing loci-written spcfile
#  detected channels : 1
# time_serieA_TP36_SP0_Z0.sdt
#  enforcing loci-written spcfile
#  detected channels : 1
# time_serieA_TP37_SP0_Z0.sdt
#  enforcing loci-written spcfile
#  detected channels : 1
# time_serieA_TP38_SP0_Z0.sdt
#  enforcing loci-written spcfile
#  detected channels : 1
# time_serieA_TP39_SP0_Z0.sdt
#  enforcing loci-written spcfile
#  detected channels : 1
# time_serieB_TP00_SP0_Z0.sdt
#  enforcing loci-written spcfile
#  detected channels : 1
# time_serieB_TP01_SP0_Z0.sdt
#  enforcing loci-written spcfile
#  detected channels : 1
# time_serieB_TP02_SP0_Z0.sdt
#  enforcing loci-written spcfile
#  detected channels : 1
# time_serieB_TP03_SP0_Z0.sdt
#  enforcing loci-written spcfile
#  detected channels : 1
# time_serieB_TP04_SP0_Z0.sdt
#  enforcing loci-written spcfile
#  detected channels : 1
# time_serieB_TP05_SP0_Z0.sdt
#  enforcing loci-written spcfile
#  detected channels : 1
# time_serieB_TP06_SP0_Z0.sdt
#  enforcing loci-written spcfile
#  detected channels : 1
# time_serieB_TP07_SP0_Z0.sdt
#  enforcing loci-written spcfile
#  detected channels : 1
# time_serieB_TP08_SP0_Z0.sdt
#  enforcing loci-written spcfile
#  detected channels : 1
# time_serieB_TP09_SP0_Z0.sdt
#  enforcing loci-written spcfile
#  detected channels : 1
# time_serieB_TP10_SP0_Z0.sdt
#  enforcing loci-written spcfile
#  detected channels : 1
# time_serieB_TP11_SP0_Z0.sdt
#  enforcing loci-written spcfile
#  detected channels : 1
# time_serieB_TP12_SP0_Z0.sdt
#  enforcing loci-written spcfile
#  detected channels : 1
# time_serieB_TP13_SP0_Z0.sdt
#  enforcing loci-written spcfile
#  detected channels : 1
# time_serieB_TP14_SP0_Z0.sdt
#  enforcing loci-written spcfile
#  detected channels : 1
# time_serieB_TP15_SP0_Z0.sdt
#  enforcing loci-written spcfile
#  detected channels : 1
# time_serieB_TP16_SP0_Z0.sdt
#  enforcing loci-written spcfile
#  detected channels : 1
# time_serieB_TP17_SP0_Z0.sdt
#  enforcing loci-written spcfile
#  detected channels : 1
# time_serieB_TP18_SP0_Z0.sdt
#  enforcing loci-written spcfile
#  detected channels : 1
# time_serieB_TP19_SP0_Z0.sdt
#  enforcing loci-written spcfile
#  detected channels : 1
# time_serieB_TP20_SP0_Z0.sdt
#  enforcing loci-written spcfile
#  detected channels : 1
# time_serieB_TP21_SP0_Z0.sdt
#  enforcing loci-written spcfile
#  detected channels : 1
# time_serieB_TP22_SP0_Z0.sdt
#  enforcing loci-written spcfile
#  detected channels : 1
# time_serieB_TP23_SP0_Z0.sdt
#  enforcing loci-written spcfile
#  detected channels : 1
# time_serieB_TP24_SP0_Z0.sdt
#  enforcing loci-written spcfile
#  detected channels : 1
# time_serieB_TP25_SP0_Z0.sdt
#  enforcing loci-written spcfile
#  detected channels : 1
# time_serieB_TP26_SP0_Z0.sdt
#  enforcing loci-written spcfile
#  detected channels : 1
# time_serieB_TP27_SP0_Z0.sdt
#  enforcing loci-written spcfile
#  detected channels : 1
# time_serieB_TP28_SP0_Z0.sdt
#  enforcing loci-written spcfile
#  detected channels : 1
# time_serieB_TP29_SP0_Z0.sdt
#  enforcing loci-written spcfile
#  detected channels : 1
# time_serieB_TP30_SP0_Z0.sdt
#  enforcing loci-written spcfile
#  detected channels : 1
# time_serieB_TP31_SP0_Z0.sdt
#  enforcing loci-written spcfile
#  detected channels : 1
# time_serieB_TP32_SP0_Z0.sdt
#  enforcing loci-written spcfile
#  detected channels : 1
# time_serieB_TP33_SP0_Z0.sdt
#  enforcing loci-written spcfile
#  detected channels : 1
# time_serieB_TP34_SP0_Z0.sdt
#  enforcing loci-written spcfile
#  detected channels : 1
# time_serieB_TP35_SP0_Z0.sdt
#  enforcing loci-written spcfile
#  detected channels : 1
# time_serieB_TP36_SP0_Z0.sdt
#  enforcing loci-written spcfile
#  detected channels : 1
# time_serieB_TP37_SP0_Z0.sdt
#  enforcing loci-written spcfile
#  detected channels : 1
# time_serieB_TP38_SP0_Z0.sdt
#  enforcing loci-written spcfile
#  detected channels : 1
# time_serieB_TP39_SP0_Z0.sdt
#  enforcing loci-written spcfile
#  detected channels : 1
# time_serieC_TP00_SP0_Z0.sdt
#  enforcing loci-written spcfile
#  detected channels : 1
# time_serieD_TP00_SP0_Z0.sdt
#  enforcing loci-written spcfile
#  detected channels : 1
# time_serieE_TP00_SP0_Z0.sdt
#  enforcing loci-written spcfile
#  detected channels : 1
# time_serieE_TP01_SP0_Z0.sdt
#  enforcing loci-written spcfile
#  detected channels : 1
# time_serieF_TP00_SP0_Z0.sdt
#  enforcing loci-written spcfile
#  detected channels : 1
# time_serieF_TP01_SP0_Z0.sdt
#  enforcing loci-written spcfile
#  detected channels : 1
# time_serieF_TP02_SP0_Z0.sdt
#  enforcing loci-written spcfile
#  detected channels : 1
# time_serieF_TP03_SP0_Z0.sdt
#  enforcing loci-written spcfile
#  detected channels : 1
# time_serieF_TP04_SP0_Z0.sdt
#  enforcing loci-written spcfile
#  detected channels : 1
# time_serieF_TP05_SP0_Z0.sdt
#  enforcing loci-written spcfile
#  detected channels : 1
# time_serieF_TP06_SP0_Z0.sdt
#  enforcing loci-written spcfile
#  detected channels : 1
# time_serieF_TP07_SP0_Z0.sdt
#  enforcing loci-written spcfile
#  detected channels : 1
# time_serieF_TP08_SP0_Z0.sdt
#  enforcing loci-written spcfile
#  detected channels : 1
# time_serieF_TP09_SP0_Z0.sdt
#  enforcing loci-written spcfile
#  detected channels : 1
# Wall time: 7.07 s

# %%
for ix,i in enumerate(fl):
    print ix, i
# Out:
# 0 time_serieA_TP00_SP0_Z0.sdt
# 1 time_serieA_TP01_SP0_Z0.sdt
# 2 time_serieA_TP02_SP0_Z0.sdt
# 3 time_serieA_TP03_SP0_Z0.sdt
# 4 time_serieA_TP04_SP0_Z0.sdt
# 5 time_serieA_TP05_SP0_Z0.sdt
# 6 time_serieA_TP06_SP0_Z0.sdt
# 7 time_serieA_TP07_SP0_Z0.sdt
# 8 time_serieA_TP08_SP0_Z0.sdt
# 9 time_serieA_TP09_SP0_Z0.sdt
# 10 time_serieA_TP10_SP0_Z0.sdt
# 11 time_serieA_TP11_SP0_Z0.sdt
# 12 time_serieA_TP12_SP0_Z0.sdt
# 13 time_serieA_TP13_SP0_Z0.sdt
# 14 time_serieA_TP14_SP0_Z0.sdt
# 15 time_serieA_TP15_SP0_Z0.sdt
# 16 time_serieA_TP16_SP0_Z0.sdt
# 17 time_serieA_TP17_SP0_Z0.sdt
# 18 time_serieA_TP18_SP0_Z0.sdt
# 19 time_serieA_TP19_SP0_Z0.sdt
# 20 time_serieA_TP20_SP0_Z0.sdt
# 21 time_serieA_TP21_SP0_Z0.sdt
# 22 time_serieA_TP22_SP0_Z0.sdt
# 23 time_serieA_TP23_SP0_Z0.sdt
# 24 time_serieA_TP24_SP0_Z0.sdt
# 25 time_serieA_TP25_SP0_Z0.sdt
# 26 time_serieA_TP26_SP0_Z0.sdt
# 27 time_serieA_TP27_SP0_Z0.sdt
# 28 time_serieA_TP28_SP0_Z0.sdt
# 29 time_serieA_TP29_SP0_Z0.sdt
# 30 time_serieA_TP30_SP0_Z0.sdt
# 31 time_serieA_TP31_SP0_Z0.sdt
# 32 time_serieA_TP32_SP0_Z0.sdt
# 33 time_serieA_TP33_SP0_Z0.sdt
# 34 time_serieA_TP34_SP0_Z0.sdt
# 35 time_serieA_TP35_SP0_Z0.sdt
# 36 time_serieA_TP36_SP0_Z0.sdt
# 37 time_serieA_TP37_SP0_Z0.sdt
# 38 time_serieA_TP38_SP0_Z0.sdt
# 39 time_serieA_TP39_SP0_Z0.sdt
# 40 time_serieB_TP00_SP0_Z0.sdt
# 41 time_serieB_TP01_SP0_Z0.sdt
# 42 time_serieB_TP02_SP0_Z0.sdt
# 43 time_serieB_TP03_SP0_Z0.sdt
# 44 time_serieB_TP04_SP0_Z0.sdt
# 45 time_serieB_TP05_SP0_Z0.sdt
# 46 time_serieB_TP06_SP0_Z0.sdt
# 47 time_serieB_TP07_SP0_Z0.sdt
# 48 time_serieB_TP08_SP0_Z0.sdt
# 49 time_serieB_TP09_SP0_Z0.sdt
# 50 time_serieB_TP10_SP0_Z0.sdt
# 51 time_serieB_TP11_SP0_Z0.sdt
# 52 time_serieB_TP12_SP0_Z0.sdt
# 53 time_serieB_TP13_SP0_Z0.sdt
# 54 time_serieB_TP14_SP0_Z0.sdt
# 55 time_serieB_TP15_SP0_Z0.sdt
# 56 time_serieB_TP16_SP0_Z0.sdt
# 57 time_serieB_TP17_SP0_Z0.sdt
# 58 time_serieB_TP18_SP0_Z0.sdt
# 59 time_serieB_TP19_SP0_Z0.sdt
# 60 time_serieB_TP20_SP0_Z0.sdt
# 61 time_serieB_TP21_SP0_Z0.sdt
# 62 time_serieB_TP22_SP0_Z0.sdt
# 63 time_serieB_TP23_SP0_Z0.sdt
# 64 time_serieB_TP24_SP0_Z0.sdt
# 65 time_serieB_TP25_SP0_Z0.sdt
# 66 time_serieB_TP26_SP0_Z0.sdt
# 67 time_serieB_TP27_SP0_Z0.sdt
# 68 time_serieB_TP28_SP0_Z0.sdt
# 69 time_serieB_TP29_SP0_Z0.sdt
# 70 time_serieB_TP30_SP0_Z0.sdt
# 71 time_serieB_TP31_SP0_Z0.sdt
# 72 time_serieB_TP32_SP0_Z0.sdt
# 73 time_serieB_TP33_SP0_Z0.sdt
# 74 time_serieB_TP34_SP0_Z0.sdt
# 75 time_serieB_TP35_SP0_Z0.sdt
# 76 time_serieB_TP36_SP0_Z0.sdt
# 77 time_serieB_TP37_SP0_Z0.sdt
# 78 time_serieB_TP38_SP0_Z0.sdt
# 79 time_serieB_TP39_SP0_Z0.sdt
# 80 time_serieC_TP00_SP0_Z0.sdt
# 81 time_serieD_TP00_SP0_Z0.sdt
# 82 time_serieE_TP00_SP0_Z0.sdt
# 83 time_serieE_TP01_SP0_Z0.sdt
# 84 time_serieF_TP00_SP0_Z0.sdt
# 85 time_serieF_TP01_SP0_Z0.sdt
# 86 time_serieF_TP02_SP0_Z0.sdt
# 87 time_serieF_TP03_SP0_Z0.sdt
# 88 time_serieF_TP04_SP0_Z0.sdt
# 89 time_serieF_TP05_SP0_Z0.sdt
# 90 time_serieF_TP06_SP0_Z0.sdt
# 91 time_serieF_TP07_SP0_Z0.sdt
# 92 time_serieF_TP08_SP0_Z0.sdt
# 93 time_serieF_TP09_SP0_Z0.sdt

# %%
matplotlib.style.use('seaborn-poster')

# %%
figure(figsize=[20,10])

for i in LT[:40]:
    plot(np.array(i).astype(float)/i.max(),'.k')

    
for i in LT[40:80]:
    plot(np.array(i).astype(float)/i.max(),'.r')

for i in LT[84:94]:
    plot(np.array(i).astype(float)/i.max(),'.b')

#for i in LT[80:]:
#    plot(np.array(i).astype(float)/i.max(),'.y')

yscale('log')
title('inconclusive- black:NADH red:NADH+NBF(low counts) blue:NADH+NBF high counts')

# %%
figure(figsize=[20,10])

ix=np.zeros_like(i)
for i in LT[:40]:
    ix=ix+(np.array(i).astype(float)/i.max())
plot(ix/40,'.k')
ix=np.zeros_like(i)
for i in LT[40:80]:
    ix=ix+(np.array(i).astype(float)/i.max())
plot(ix/40,'.r')
ix=np.zeros_like(i)
for i in LT[84:93]:
    ix=ix+(np.array(i).astype(float)/i.max())
plot(ix/9,'.b')

yscale('log')
legend(['NADH 30mM','NADH + NBF @same power','NADH+NBF @higher power'])

# %%
# %pylab
# %matplotlib inline
# Out:
# Using matplotlib backend: TkAgg
# Populating the interactive namespace from numpy and matplotlib

# %%
imshow(data.sum(0))

# %%
plot(data[:,:128,:128].sum(2).sum(1),'.k')
plot(data[:,:128,128:].sum(2).sum(1),'.g')
plot(data[:,128:,:128].sum(2).sum(1),'.r')
plot(data[:,128:,128:].sum(2).sum(1),'.b')
yscale('log')
